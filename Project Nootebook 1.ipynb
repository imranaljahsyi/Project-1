# %% [markdown]
# #  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Imran Loutfi AlJahsyi bin Ali**
# Sponsorship Consultant

# %% [markdown]
# *I am interested in data science because I am  intrigued by the power of how information can be gathered, managed, structured and visualised to provide valuable insights for an entity that depends on knowledge to measure and empower growth.*

# %% [markdown]
# ### The following code will find the area of a circle

# %%
def findArea(r): 
    PI = 3.142
    return PI * (r*r); 
  
# Driver method
print("Area of the circle is %.6f" % findArea(5));
# Out:
# Area of the circle is 78.550000

# %% [markdown]
# **1. Table**:
#
# **Name** | **Age** | **Occupation**
# --- | --- | ---
# Imran AlJahsyi | 25 | A
#
# **2. Numbered List**
# 1. This
# 2. Is
# 3. A
# 4. List
#
# **3. Hyperlink**
#
# [Click here to access Google](https://www.google.com)
#
# **4. Image**
# ![alt text][logo]
#
# [logo]: https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 2"

# %%
for x in ['A','B','C']:

  print(x+'A')
# Out:
# AA
# BA
# CA

# %%
plus('a','b')
# Out:
# 'ab'
